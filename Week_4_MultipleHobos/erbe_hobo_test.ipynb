# %%
import erbe_hobo as eh

# %%
df=eh.read_hobo_file('sensor1_ben.csv',convert_to_farenheit=True)
df.head()
# Out:
# sensor1_ben.csv
# variable_name          #                                 Temp  \
# units                NaN                                   °F
# serial_text          NaN LGR S/N: 10469238, SEN S/N: 10469238
# Date Time, GMT+00:00
# 2014-03-31 07:00:00    1                               69.622
# 2014-03-31 07:30:00    2                               69.622
# 2014-03-31 08:00:00    3                               69.449
# 2014-03-31 08:30:00    4                               69.622
# 2014-03-31 09:00:00    5                               69.964
#
# variable_name         Coupler Attached    Host Connected           Stopped  \
# units                              NaN               NaN               NaN
# serial_text          LGR S/N: 10469238 LGR S/N: 10469238 LGR S/N: 10469238
# Date Time, GMT+00:00
# 2014-03-31 07:00:00                NaN               NaN               NaN
# 2014-03-31 07:30:00                NaN               NaN               NaN
# ...
